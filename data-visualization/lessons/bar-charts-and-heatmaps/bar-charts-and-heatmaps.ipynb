# %% [markdown]
# # Lesson 3 bar-charts-and-heatmaps

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Practice starts here

flight_filepath = "../input/data-for-datavis/flight_delays.csv"
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# %%
flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
# Seaborn gives error when ploting lineplot of more than 6
# lines dashed

plt.figure(figsize=(14,6))
sns.lineplot(data=flight_data, dashes=False)

# %%
# ploting Bar chart
plt.figure(figsize=(10,6))

plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
plt.ylabel("Arrival delay (in minutes)")
sns.barplot(x=flight_data.index, y=flight_data['NK'])
# Important Note: You must select the indexing column with 
# flight_data.index, and it is not possible to use 
# flight_data['Month'] (which will return an error). This
# is because when we loaded the dataset, the "Month" column 
# was used to index the rows. We always have to use this 
# special notation to select the indexing column.

# %%
plt.figure(figsize=(14,7))
plt.title("Average Arrival Delay for Each Airline, by Month")
sns.heatmap(data=flight_data, annot=True)
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %%
# Practice ends here
# %reset -f # reseting environment
# Out:
# Don't know how to reset  #, please run `%reset?` for details
# Don't know how to reset  reseting, please run `%reset?` for details
# Don't know how to reset  environment, please run `%reset?` for details

# %% [markdown]
# # Exercise: Bar Charts and Heatmaps
# #### In this exercise, you will use your new knowledge to propose a solution to a real-world scenario. To succeed, you will need to import data into Python, answer questions using the data, and generate bar charts and heatmaps to understand patterns in the data.

# %% [markdown]
# ### Scenario
# ##### You've recently decided to create your very own video game! As an avid reader of IGN Game Reviews, you hear about all of the most recent game releases, along with the ranking they've received from experts, ranging from 0 (Disaster) to 10 (Masterpiece). You're interested in using IGN reviews to guide the design of your upcoming game. Thankfully, someone has summarized the rankings in a really useful CSV file that you can use to guide your analysis.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Loading csv data into python

ign_filepath = "../input/data-for-datavis/ign_scores.csv"
ign_data = pd.read_csv(ign_filepath, index_col="Platform")

# %%
ign_data
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
[ign_data.loc["PlayStation Vita"].max() == ign_data[i] for i in list(ign_data.columns)]
ign_data.max().max()
# Out:
# 9.25

# %%
list(ign_data.columns)
# Out:
# ['Action',
#  'Action, Adventure',
#  'Adventure',
#  'Fighting',
#  'Platformer',
#  'Puzzle',
#  'RPG',
#  'Racing',
#  'Shooter',
#  'Simulation',
#  'Sports',
#  'Strategy']

# %%
[i for i in list(ign_data.columns)]
# Out:
# ['Action',
#  'Action, Adventure',
#  'Adventure',
#  'Fighting',
#  'Platformer',
#  'Puzzle',
#  'RPG',
#  'Racing',
#  'Shooter',
#  'Simulation',
#  'Sports',
#  'Strategy']

# %%
plt.figure(figsize=(16, 6))
sns.set(style='darkgrid')
sns.barplot(x=ign_data.index, y=ign_data["Racing"])

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(data=ign_data, annot=True)
