# %% [markdown]
# # Kaggle Lesson 1 on Data Visualisation

# %%
# There are no real exercises here just practice only
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
type(sns)
# Out:
# module

# %%
import os
if not os.path.exists("../input/fifa.csv"):
    os.symlink("../input/data-for-datavis/fifa.csv", "../input/fifa.csv")

# %%
fifa_filepath = "../input/fifa.csv"

fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %%
plt.figure(figsize=(16,6))

# %%
sns.lineplot(data=fifa_data)

# %%
sns.boxplot(data=fifa_data)

# %%
sns.catplot(data=fifa_data)
