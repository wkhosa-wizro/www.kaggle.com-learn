# %% [markdown]
# # Pandas lesson 1 from kaggle
# ## Creating, Reading and Writing

# %%
import pandas as pd

# %%
# Creating a Dataframe
fruits = pd.DataFrame(data=[[30, 21]], columns=["Apples", "Bannas"])

# %%
fruits
# Out:
#    Apples  Bannas
# 0      30      21

# %%
fruit_sales = pd.DataFrame(data={"Apples" : [35, 41], "Bananas" : [21, 34]}, index=["2017 sales", "2018 sales"])
fruit_sales_alt = pd.DataFrame(data=[[35, 21], [41, 34]], columns=["Apples", "Bananas"], index=["2017 sales", "2018 sales"])

# %%
fruit_sales
# Out:
#             Apples  Bananas
# 2017 sales      35       21
# 2018 sales      41       34

# %%
fruit_sales_alt
# Out:
#             Apples  Bananas
# 2017 sales      35       21
# 2018 sales      41       34

# %%
#
ingredients = pd.Series(data={"Flour":"4 cups", "Milk": "1 cup", "Eggs": "2 large", "Spam" : "1 can"}, name='Dinner')
ingredients_alt = pd.Series(data=["4 cups", "1 cup", "2 large", "1 can"], index=["Flour", "Milk", "Eggs", "Spam"], name="Dinner")

# %%
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
ingredients_alt
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
# Reading csv file
# The filepath to the csv file is ../input/wine-reviews/winemag-data_first150k.csv
reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv')

# %%
reviews
# Out:
#         Unnamed: 0      country  \
# 0                0           US
# 1                1        Spain
# 2                2           US
# 3                3           US
# 4                4       France
# 5                5        Spain
# 6                6        Spain
# 7                7        Spain
# 8                8           US
# 9                9           US
# 10              10        Italy
# 11              11           US
# 12              12           US
# 13              13       France
# 14              14           US
# 15              15           US
# 16              16           US
# 17              17        Spain
# 18              18       France
# 19              19           US
# 20              20           US
# 21              21        Spain
# 22              22        Spain
# 23              23           US
# 24              24           US
# 25              25  New Zealand
# 26              26           US
# 27              27           US
# ...
